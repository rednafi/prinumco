# %%
from PIL import ImageFilter, Image

# %%
# %matplotlib inline

# %%
from glob import glob

# %%
images = glob('./train/*/*')

# %%
img = Image.open(images[0])

# %%
img
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=256x256 at 0x7F84AD453EF0>

# %%
img.filter(ImageFilter.SHARPEN)
# Out:
# <PIL.Image.Image image mode=RGB size=256x256 at 0x7F84F9FEBBE0>

# %%
img.filter(ImageFilter.BoxBlur(0.1))
# Out:
# <PIL.Image.Image image mode=RGB size=256x256 at 0x7F84ACFAAF60>
